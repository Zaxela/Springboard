# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('adult.csv')
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data = pd.read_csv('adult.csv')

data = data[data.age >= 22]
data = data[data.age <= 28]

rows = ['HS-grad', 'Some-college', 'Bachelors', 'Masters']
data = data[data.education.isin(rows)]
data.education.value_counts()
# Out:
# HS-grad         2677
# Some-college    2233
# Bachelors       1826
# Masters          198
# Name: education, dtype: int64

# %%
data = data.loc[:, ['education', 'income']]
data
# Out:
#           education income
# 8      Some-college  <=50K
# 12          HS-grad  <=50K
# 23        Bachelors  <=50K
# 24        Bachelors  <=50K
# 26          HS-grad  <=50K
# ...             ...    ...
# 48792     Bachelors  <=50K
# 48801       HS-grad  <=50K
# 48808  Some-college  <=50K
# 48836  Some-college  <=50K
# 48840       HS-grad  <=50K
#
# [6934 rows x 2 columns]

# %%
df = pd.get_dummies(data, columns=data.columns[1:])
df['income_>50K'].replace(to_replace=0, value=1, inplace=True)
df2 = df.groupby(by='education').sum()

index = ['HS-grad', 'Some-college', 'Bachelors', 'Masters']
df2 = df2.reindex(index)
df2
# Out:
#               income_<=50K  income_>50K
# education
# HS-grad             2563.0       2677.0
# Some-college        2121.0       2233.0
# Bachelors           1635.0       1826.0
# Masters              169.0        198.0

# %%
df2.plot.bar()
plt.ylabel('Count of Adults')
plt.title('Income Group of Adults in the Age Group of 22 to 28')
# Out:
# Text(0.5, 1.0, 'Income Group of Adults in the Age Group of 22 to 28')
